plot()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning:
#
# 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")

# %%
data=pd.concat([totseret_m,Na_m],axis=1)
data.head(25)
# Out:
#               tons    Na
# date
# 2018-01-01  4864.0   NaN
# 2018-01-02  4864.0   NaN
# 2018-01-03  4864.0   NaN
# 2018-01-04  4864.0   NaN
# 2018-01-05  4864.0   NaN
# 2018-01-06  4864.0   NaN
# 2018-01-07  4864.0   NaN
# 2018-01-08  4864.0   NaN
# 2018-01-09  4864.0   NaN
# 2018-01-10  4864.0   NaN
# 2018-01-11  4864.0   NaN
# 2018-01-12  4864.0   NaN
# 2018-01-13  4864.0   NaN
# 2018-01-14  4864.0   NaN
# 2018-01-15  4864.0   NaN
# 2018-01-16  4864.0   NaN
# 2018-01-17  4864.0   NaN
# 2018-01-18  4864.0   NaN
# 2018-01-19  4864.0   NaN
# 2018-01-20  4864.0   NaN
# 2018-01-21  4864.0  5.58
# 2018-01-22  4864.0  5.58
# 2018-01-23  4864.0  5.58
# 2018-01-24  4864.0  5.58
# 2018-01-25  4864.0  5.58

# %%
fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=data.index, y=data.tons, mode='markers+lines', name='tons', line_color='red', marker_size=4, opacity=1))
fig.add_trace(go.Scatter(x=data.index, y=data.Na, mode='markers+lines', name='Na', line_color='green', marker_size=4, opacity=1), secondary_y=True)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1efc5ab9-b91b-450b-b644-98b12cf7655e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1efc5ab9-b91b-450b-b644-98b12cf7655e")) {
#                     Plotly.newPlot(
#                         '1efc5ab9-b91b-450b-b644-98b12cf7655e',
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter(x=data.Na, y=data.tons, mode='markers', name='tons', line_color='red', marker_size=4, opacity=1))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="669cd27c-3aea-4c41-ab46-6d1bddaacad4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("669cd27c-3aea-4c41-ab46-6d1bddaacad4")) {
#                     Plotly.newPlot(
#                         '669cd27c-3aea-4c41-ab46-6d1bddaacad4',
# ...

# %% [markdown]
# # גרף אוטומטי עם זמן משותף

# %%
period='6h'
df1=totseret.resample(period, loffset='0d').mean().interpolate('polynomial',order=0)
df2=Na.resample(period, loffset='0d').mean().interpolate('polynomial',order=0)

fig = go.Figure()
fig = make_subplots(specs=[[{"secondary_y": True}]])
fig.add_trace(go.Scatter(x=df1.index, y=df1.tons, mode='markers+lines', name='tons', line_color='red', marker_size=4, opacity=1))
fig.add_trace(go.Scatter(x=df2.index, y=df2.Na, mode='markers+lines', name='Na', line_color='green', marker_size=4, opacity=1), secondary_y=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
#
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning:
#
# 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...

# %%
period='m'
df1=totseret.resample(period, loffset='0d').mean().interpolate('polynomial',order=0)
df2=Na.resample(period, loffset='0d').mean().interpolate('polynomial',order=0)

fig = go.Figure()
fig.add_trace(go.Scatter(x=df2.Na, y=df1.tons, mode='markers', name='tons', line_color='red', marker_size=4, opacity=1))
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning:
#
# 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
#
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: FutureWarning:
#
# 'loffset' in .resample() and in Grouper() is deprecated.
#
# >>> df.resample(freq="3s", loffset="8H")
#
# becomes:
#
# >>> from pandas.tseries.frequencies import to_offset
# >>> df = df.resample(freq="3s").mean()
# >>> df.index = df.index.to_timestamp() + to_offset("8H")
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
# ...
